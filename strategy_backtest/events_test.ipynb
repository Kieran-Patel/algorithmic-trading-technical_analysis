# %%
# %run BacktestLongOnly.py
# Out:
# Running SMA strategy | SMA1=5 & SMA2=20
# fixed costs 10.0 | proportional costs 0.01
# ...
# 2019-02-01 00:00:00 | BUYING 6 units at 166.52
# 2019-02-01 00:00:00 | current balance -19.11
# 2019-02-01 00:00:00 | current net wealth 980.01
# 2019-05-10 00:00:00 | SELLING 6 units at 197.18
# 2019-05-10 00:00:00 | current balance 1142.14
# 2019-05-10 00:00:00 | current net wealth 1142.14
# 2019-06-10 00:00:00 | BUYING 5 units at 192.58
# 2019-06-10 00:00:00 | current balance 159.61
# 2019-06-10 00:00:00 | current net wealth 1122.51
# 2019-08-06 00:00:00 | SELLING 5 units at 197.00
# 2019-08-06 00:00:00 | current balance 1124.76
# 2019-08-06 00:00:00 | current net wealth 1124.76
# 2019-08-19 00:00:00 | BUYING 5 units at 210.35
# 2019-08-19 00:00:00 | current balance 52.49
# 2019-08-19 00:00:00 | current net wealth 1104.24
# 2019-12-05 00:00:00 | SELLING 5 units at 265.58
# 2019-12-05 00:00:00 | current balance 1357.11
# 2019-12-05 00:00:00 | current net wealth 1357.11
# ...
